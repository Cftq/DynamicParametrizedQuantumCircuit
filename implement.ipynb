# %% [markdown]
# ### Measured 1 Unitary PQC
#
# VQE -> QFIM / Hessian -> visualization (for each h).

# %%
# h = 0.1
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.1 --stage vqe

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.1

# %%
# h = 0.5
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.5 --stage vqe

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.5

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.5

# %%
# h = 0.9
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.9 --stage vqe

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.9

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.9

# %% [markdown]
# ### Reset DPQC

# %%
# h = 0.1
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.1 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.1

# %%
# !python src/dpqc/DPQC_overparam_reset_visualize.py --h-param 0.1

# %%
# h = 0.5
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.5 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.5

# %%
# !python src/dpqc/DPQC_overparam_reset_visualize.py --h-param 0.5

# %%
# h = 0.9
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.9 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_reset_compute.py --h-param 0.9

# %%
# !python src/dpqc/DPQC_overparam_reset_visualize.py --h-param 0.9

# %% [markdown]
# ### DPQC
#
# VQE -> QFIM / Hessian -> visualization (for each h).

# %%
# h = 0.1
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.1 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.1

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --h-param 0.1

# %%
# h = 0.5
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.5 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.5

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --h-param 0.5

# %%
# h = 0.9
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.9 --stage vqe

# %%
# !python src/dpqc/DPQC_overparam_compute.py --h-param 0.9

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --h-param 0.9
