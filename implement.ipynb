# %%
# !python src/dpqc/DPQC_overparam_compute.py

# %%
# !python src/dpqc/DPQC_overparam_visualize.py
# Out:
# Saved figures to: ./figs/dpqc/h_0.1
# c:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\src\dpqc\DPQC_overparam_visualize.py:797: RuntimeWarning: Skipping multiple-accuracy success-probability figure: invalid archive ./figs/dpqc/h_0.1\numerical_results\energy\vqe_success_probability_multiple_tolerances.npz: 'thresholds' must contain the 11 configured positive finite accuracy levels
#   _warn_skip_success_probability_figure(
#
# ...
# QFIM eig distributions along optimization path: 100%|██████████| 16/16 [00:58<00:00,  3.65s/layer]
#
# ...
# QFIM eig distributions along optimization path: 100%|██████████| 16/16 [00:56<00:00,  3.56s/layer]

# %%
# !python src/dpqc/DPQC_overparam_draw_circuits.py
# Out:
# L=1: selected run 10 (final energy=-3.999999999459702); saved C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\optimized_circuits\optimized_circuit_L1.png
# L=2: selected run 7 (final energy=-3.999999999960833); saved C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\optimized_circuits\optimized_circuit_L2.png
# L=3: selected run 9 (final energy=-3.999999999999998); saved C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\optimized_circuits\optimized_circuit_L3.png
# L=4: selected run 19 (final energy=-3.999999999999998); saved C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\optimized_circuits\optimized_circuit_L4.png
# L=5: selected run 14 (final energy=-3.999999999999468); saved C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\optimized_circuits\optimized_circuit_L5.png
# ...

# %%
# !python src/dpqc/DPQC_overparam_compute_pure.py
# Out:
# Saved pure-state DPQC results to: C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\numerical_results\pure
# ...
# Pure VQE runs (L=1): 100%|██████████| 100/100 [01:53<00:00,  1.05s/it]
#
#
# ...
# Pure VQE runs (L=2): 100%|██████████| 100/100 [02:55<00:00,  1.76s/it]
#
#
# ...
# Pure VQE runs (L=3): 100%|██████████| 100/100 [03:22<00:00,  2.04s/it]
#
#
# ...
# Pure VQE runs (L=4): 100%|██████████| 100/100 [02:36<00:00,  2.09s/it]
#
#
# ...
# Pure VQE runs (L=5): 100%|██████████| 100/100 [04:11<00:00,  1.19s/it]
#
#
# ...
# Pure VQE runs (L=6): 100%|██████████| 100/100 [03:03<00:00,  1.70s/it]
#
#
# ...
# Pure VQE runs (L=7):  72%|███████▏  | 72/100 [07:00<03:08,  6.73s/it]
# ...
# ...
# Pure VQE runs (L=7): 100%|██████████| 100/100 [09:59<00:00,  3.87s/it]
#
#
# ...
# Pure QFIM samples (L=1):   1%|          | 1/100 [00:00<00:47,  2.07it/s]
#
#
# ...
# Pure path QFIM (L=1):  68%|██████▊   | 68/100 [00:00<00:00, 655.54it/s]
#
#
# ...
# Pure QFIM samples (L=2):   1%|          | 1/100 [00:01<01:48,  1.10s/it]
#
#
# ...

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --pure-only
# Out:
# Saved 981 pure-state figures to: C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.1\figures\pure

# %%
# !python src/unitary_pqc/unitary_pqc_overparam_compute.py

# %%
# !python src/dpqc/DPQC_overparam_visualize.py

# %%
# !python src/unitary_pqc/unitary_pqc_overparam_visualize.py

# %%
# !python src/dpqc/DPQC_overparam_compute_postselected.py
# Out:
# L=1: saved 100 sampled-trajectory VQE runs; final sampled conditional error min=0.0615528, mean=1.69104, max=4.06155; post-hoc ensemble error mean=1.71461 -> figs\dpqc\h_0.5\numerical_results\postselected\optimization_L1.npz
# L=2: saved 100 sampled-trajectory VQE runs; final sampled conditional error min=0.0615528, mean=1.9172, max=4.06155; post-hoc ensemble error mean=1.68276 -> figs\dpqc\h_0.5\numerical_results\postselected\optimization_L2.npz
# L=3: saved 100 sampled-trajectory VQE runs; final sampled conditional error min=0.0615528, mean=1.61268, max=3.06454; post-hoc ensemble error mean=1.43142 -> figs\dpqc\h_0.5\numerical_results\postselected\optimization_L3.npz
# L=4: saved 100 sampled-trajectory VQE runs; final sampled conditional error min=0.0615534, mean=1.3225, max=3.06169; post-hoc ensemble error mean=1.22071 -> figs\dpqc\h_0.5\numerical_results\postselected\optimization_L4.npz
# ...

# %%
# !python src/dpqc/DPQC_overparam_visualize_postselected.py
# Out:
# Saved one-count-grouped QFIM rank PDF (9 pages): C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.5\figures\postselected\qfim\rank\random_points\trajectory_qfim_rank_all_samples_by_one_count_postselected_keep0123.pdf
# Saved one-count-grouped QFIM rank PDF (9 pages): C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.5\figures\postselected\qfim\rank\random_points\trajectory_qfim_rank_all_samples_by_one_count_postselected_keep01234.pdf
# ...
# Saved one-count-grouped optimized-energy summary PDF (8 pages): C:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc\h_0.5\figures\postselected\energy\optimization\trajectory_energy_error_one_count_run_means_min_mean_sem_max_vqe_optimized_postselected.pdf
# ...
