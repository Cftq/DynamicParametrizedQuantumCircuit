# %%
# !python src/dpqc/DPQC_overparam_vqe.py

# %%
# !python src/dpqc/DPQC_overparam_qfim.py

# %%
# !python src/dpqc/DPQC_overparam_visualize.py

# %%
# !python src/dpqc/DPQC_overparam_draw_circuits.py

# %%
# !python src/dpqc/DPQC_overparam_compute_pure.py

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --pure-only

# %%
# !python src/dpqc/DPQC_overparam_visualize.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_compute.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_visualize.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.1

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_compute.py --h-param 0.5

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.5

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_visualize.py --h-param 0.5

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.5

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_compute.py --h-param 0.9

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_compute.py --h-param 0.9

# %%
# !python src/unitary_pqc/unitary_pqc_measured_0_overparam_visualize.py --h-param 0.9

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_visualize.py --h-param 0.9

# %%
# !python src/unitary_pqc/unitary_pqc_measured_1_overparam_draw_circuits.py

# %%
# !python src\dpqc\DPQC_overparam_reset_compute.py --h-param 0.1
# Out:
# Running reset-DPQC with P(L)=12L and fixed Rx(pi).
# VQE optimizer: Deterministic Gradient Descent (learning_rate=0.001)
# Saved reset-DPQC VQE results to: c:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc_reset\h_0.1\numerical_results\energy
# Saved reset-DPQC model metadata to: c:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc_reset\h_0.1\reset_model_metadata.json
# Saved random-point QFIM numerical results to: c:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc_reset\h_0.1\numerical_results\qfim
# Saved reset-DPQC random-point QFIM results to: c:\Users\hkent\OneDrive\デスクトップ\DynamicParametrizedQuantumCircuit\figs\dpqc_reset\h_0.1\numerical_results\qfim
# Layers (VQE):   0%|          | 0/8 [00:00<?, ?layer/s]
#
# Run batches (L=1, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=1, batch=20): 100%|██████████| 1/1 [00:13<00:00, 13.89s/batch]
#
#
# Layers (VQE):  12%|█▎        | 1/8 [00:14<01:40, 14.37s/layer]
#
# Run batches (L=2, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=2, batch=20): 100%|██████████| 1/1 [01:19<00:00, 79.46s/batch]
#
#
# Layers (VQE):  25%|██▌       | 2/8 [01:34<05:18, 53.05s/layer]
#
# Run batches (L=3, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=3, batch=20): 100%|██████████| 1/1 [02:32<00:00, 152.91s/batch]
#
#
# Layers (VQE):  38%|███▊      | 3/8 [04:08<08:14, 98.99s/layer]
#
# Run batches (L=4, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=4, batch=20): 100%|██████████| 1/1 [03:37<00:00, 217.02s/batch]
#
#
# Layers (VQE):  50%|█████     | 4/8 [07:45<09:43, 145.88s/layer]
#
# Run batches (L=5, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=5, batch=20): 100%|██████████| 1/1 [03:59<00:00, 239.90s/batch]
#
#
# Layers (VQE):  62%|██████▎   | 5/8 [11:46<09:00, 180.07s/layer]
#
# Run batches (L=6, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=6, batch=20): 100%|██████████| 1/1 [03:59<00:00, 239.46s/batch]
#
#
# Layers (VQE):  75%|███████▌  | 6/8 [15:46<06:41, 200.52s/layer]
#
# Run batches (L=7, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=7, batch=20): 100%|██████████| 1/1 [04:37<00:00, 277.60s/batch]
#
#
# Layers (VQE):  88%|████████▊ | 7/8 [20:25<03:45, 225.97s/layer]
#
# Run batches (L=8, batch=20):   0%|          | 0/1 [00:00<?, ?batch/s]
#
# Run batches (L=8, batch=20): 100%|██████████| 1/1 [04:37<00:00, 277.62s/batch]
#
#
# Layers (VQE): 100%|██████████| 8/8 [25:03<00:00, 242.64s/layer]
# Layers (VQE): 100%|██████████| 8/8 [25:03<00:00, 187.94s/layer]
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):   0%|          | 0/17 [00:00<?, ?layer/s]
#
# QFIM samples for both kept states (L=1):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=1):  10%|█         | 1/10 [00:01<00:14,  1.65s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):   6%|▌         | 1/17 [00:01<00:29,  1.85s/layer]
#
# QFIM samples for both kept states (L=2):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=2):  10%|█         | 1/10 [00:02<00:23,  2.64s/sample]
#
# QFIM samples for both kept states (L=2):  60%|██████    | 6/10 [00:02<00:01,  2.91sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  12%|█▏        | 2/17 [00:04<00:37,  2.51s/layer]
#
# QFIM samples for both kept states (L=3):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=3):  10%|█         | 1/10 [00:03<00:28,  3.14s/sample]
#
# QFIM samples for both kept states (L=3):  40%|████      | 4/10 [00:03<00:03,  1.59sample/s]
#
# QFIM samples for both kept states (L=3):  70%|███████   | 7/10 [00:03<00:00,  3.20sample/s]
#
# QFIM samples for both kept states (L=3): 100%|██████████| 10/10 [00:03<00:00,  5.12sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  18%|█▊        | 3/17 [00:08<00:42,  3.07s/layer]
#
# QFIM samples for both kept states (L=4):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=4):  10%|█         | 1/10 [00:02<00:24,  2.77s/sample]
#
# QFIM samples for both kept states (L=4):  30%|███       | 3/10 [00:02<00:05,  1.30sample/s]
#
# QFIM samples for both kept states (L=4):  50%|█████     | 5/10 [00:03<00:02,  2.46sample/s]
#
# QFIM samples for both kept states (L=4):  70%|███████   | 7/10 [00:03<00:00,  3.80sample/s]
#
# QFIM samples for both kept states (L=4):  90%|█████████ | 9/10 [00:03<00:00,  5.29sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  24%|██▎       | 4/17 [00:12<00:42,  3.26s/layer]
#
# QFIM samples for both kept states (L=5):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=5):  10%|█         | 1/10 [00:03<00:32,  3.60s/sample]
#
# QFIM samples for both kept states (L=5):  30%|███       | 3/10 [00:03<00:07,  1.01s/sample]
#
# QFIM samples for both kept states (L=5):  50%|█████     | 5/10 [00:03<00:02,  1.86sample/s]
#
# QFIM samples for both kept states (L=5):  70%|███████   | 7/10 [00:04<00:01,  2.86sample/s]
#
# QFIM samples for both kept states (L=5):  80%|████████  | 8/10 [00:04<00:00,  3.41sample/s]
#
# QFIM samples for both kept states (L=5):  90%|█████████ | 9/10 [00:04<00:00,  4.07sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  29%|██▉       | 5/17 [00:16<00:45,  3.79s/layer]
#
# QFIM samples for both kept states (L=6):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=6):  10%|█         | 1/10 [00:04<00:37,  4.11s/sample]
#
# QFIM samples for both kept states (L=6):  20%|██        | 2/10 [00:04<00:14,  1.78s/sample]
#
# QFIM samples for both kept states (L=6):  30%|███       | 3/10 [00:04<00:07,  1.03s/sample]
#
# QFIM samples for both kept states (L=6):  40%|████      | 4/10 [00:04<00:04,  1.46sample/s]
#
# QFIM samples for both kept states (L=6):  50%|█████     | 5/10 [00:04<00:02,  2.04sample/s]
#
# QFIM samples for both kept states (L=6):  60%|██████    | 6/10 [00:04<00:01,  2.68sample/s]
#
# QFIM samples for both kept states (L=6):  70%|███████   | 7/10 [00:04<00:00,  3.39sample/s]
#
# QFIM samples for both kept states (L=6):  80%|████████  | 8/10 [00:05<00:00,  4.02sample/s]
#
# QFIM samples for both kept states (L=6):  90%|█████████ | 9/10 [00:05<00:00,  4.60sample/s]
#
# QFIM samples for both kept states (L=6): 100%|██████████| 10/10 [00:05<00:00,  5.17sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  35%|███▌      | 6/17 [00:22<00:48,  4.40s/layer]
#
# QFIM samples for both kept states (L=7):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=7):  10%|█         | 1/10 [00:04<00:40,  4.52s/sample]
#
# QFIM samples for both kept states (L=7):  20%|██        | 2/10 [00:04<00:15,  1.97s/sample]
#
# QFIM samples for both kept states (L=7):  30%|███       | 3/10 [00:04<00:08,  1.16s/sample]
#
# QFIM samples for both kept states (L=7):  40%|████      | 4/10 [00:05<00:04,  1.29sample/s]
#
# QFIM samples for both kept states (L=7):  50%|█████     | 5/10 [00:05<00:02,  1.78sample/s]
#
# QFIM samples for both kept states (L=7):  60%|██████    | 6/10 [00:05<00:01,  2.28sample/s]
#
# QFIM samples for both kept states (L=7):  70%|███████   | 7/10 [00:05<00:01,  2.81sample/s]
#
# QFIM samples for both kept states (L=7):  80%|████████  | 8/10 [00:05<00:00,  3.32sample/s]
#
# QFIM samples for both kept states (L=7):  90%|█████████ | 9/10 [00:06<00:00,  3.80sample/s]
#
# QFIM samples for both kept states (L=7): 100%|██████████| 10/10 [00:06<00:00,  4.17sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  41%|████      | 7/17 [00:28<00:50,  5.05s/layer]
#
# QFIM samples for both kept states (L=8):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=8):  10%|█         | 1/10 [00:04<00:40,  4.52s/sample]
#
# QFIM samples for both kept states (L=8):  20%|██        | 2/10 [00:04<00:16,  2.01s/sample]
#
# QFIM samples for both kept states (L=8):  30%|███       | 3/10 [00:05<00:08,  1.20s/sample]
#
# QFIM samples for both kept states (L=8):  40%|████      | 4/10 [00:05<00:04,  1.21sample/s]
#
# QFIM samples for both kept states (L=8):  50%|█████     | 5/10 [00:05<00:03,  1.61sample/s]
#
# QFIM samples for both kept states (L=8):  60%|██████    | 6/10 [00:05<00:01,  2.04sample/s]
#
# QFIM samples for both kept states (L=8):  70%|███████   | 7/10 [00:06<00:01,  2.41sample/s]
#
# QFIM samples for both kept states (L=8):  80%|████████  | 8/10 [00:06<00:00,  2.76sample/s]
#
# QFIM samples for both kept states (L=8):  90%|█████████ | 9/10 [00:06<00:00,  3.10sample/s]
#
# QFIM samples for both kept states (L=8): 100%|██████████| 10/10 [00:06<00:00,  3.33sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  47%|████▋     | 8/17 [00:35<00:50,  5.64s/layer]
#
# QFIM samples for both kept states (L=12):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=12):  10%|█         | 1/10 [00:06<00:56,  6.25s/sample]
#
# QFIM samples for both kept states (L=12):  20%|██        | 2/10 [00:06<00:23,  2.89s/sample]
#
# QFIM samples for both kept states (L=12):  30%|███       | 3/10 [00:07<00:12,  1.81s/sample]
#
# QFIM samples for both kept states (L=12):  40%|████      | 4/10 [00:07<00:07,  1.31s/sample]
#
# QFIM samples for both kept states (L=12):  50%|█████     | 5/10 [00:08<00:05,  1.04s/sample]
#
# QFIM samples for both kept states (L=12):  60%|██████    | 6/10 [00:08<00:03,  1.16sample/s]
#
# QFIM samples for both kept states (L=12):  70%|███████   | 7/10 [00:09<00:02,  1.33sample/s]
#
# QFIM samples for both kept states (L=12):  80%|████████  | 8/10 [00:09<00:01,  1.47sample/s]
#
# QFIM samples for both kept states (L=12):  90%|█████████ | 9/10 [00:10<00:00,  1.58sample/s]
#
# QFIM samples for both kept states (L=12): 100%|██████████| 10/10 [00:11<00:00,  1.67sample/s]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  53%|█████▎    | 9/17 [00:46<00:58,  7.37s/layer]
#
# QFIM samples for both kept states (L=16):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=16):  10%|█         | 1/10 [00:08<01:13,  8.13s/sample]
#
# QFIM samples for both kept states (L=16):  20%|██        | 2/10 [00:09<00:31,  3.91s/sample]
#
# QFIM samples for both kept states (L=16):  30%|███       | 3/10 [00:10<00:17,  2.56s/sample]
#
# QFIM samples for both kept states (L=16):  40%|████      | 4/10 [00:10<00:11,  1.90s/sample]
#
# QFIM samples for both kept states (L=16):  50%|█████     | 5/10 [00:11<00:07,  1.56s/sample]
#
# QFIM samples for both kept states (L=16):  60%|██████    | 6/10 [00:12<00:05,  1.35s/sample]
#
# QFIM samples for both kept states (L=16):  70%|███████   | 7/10 [00:13<00:03,  1.22s/sample]
#
# QFIM samples for both kept states (L=16):  80%|████████  | 8/10 [00:14<00:02,  1.13s/sample]
#
# QFIM samples for both kept states (L=16):  90%|█████████ | 9/10 [00:15<00:01,  1.07s/sample]
#
# QFIM samples for both kept states (L=16): 100%|██████████| 10/10 [00:16<00:00,  1.05s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  59%|█████▉    | 10/17 [01:03<01:12, 10.29s/layer]
#
# QFIM samples for both kept states (L=20):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=20):  10%|█         | 1/10 [00:10<01:33, 10.44s/sample]
#
# QFIM samples for both kept states (L=20):  20%|██        | 2/10 [00:11<00:41,  5.18s/sample]
#
# QFIM samples for both kept states (L=20):  30%|███       | 3/10 [00:13<00:24,  3.46s/sample]
#
# QFIM samples for both kept states (L=20):  40%|████      | 4/10 [00:14<00:16,  2.70s/sample]
#
# QFIM samples for both kept states (L=20):  50%|█████     | 5/10 [00:16<00:11,  2.25s/sample]
#
# QFIM samples for both kept states (L=20):  60%|██████    | 6/10 [00:17<00:07,  2.00s/sample]
#
# QFIM samples for both kept states (L=20):  70%|███████   | 7/10 [00:19<00:05,  1.84s/sample]
#
# QFIM samples for both kept states (L=20):  80%|████████  | 8/10 [00:20<00:03,  1.71s/sample]
#
# QFIM samples for both kept states (L=20):  90%|█████████ | 9/10 [00:22<00:01,  1.65s/sample]
#
# QFIM samples for both kept states (L=20): 100%|██████████| 10/10 [00:23<00:00,  1.61s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  65%|██████▍   | 11/17 [01:27<01:26, 14.49s/layer]
#
# QFIM samples for both kept states (L=24):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=24):  10%|█         | 1/10 [00:12<01:51, 12.44s/sample]
#
# QFIM samples for both kept states (L=24):  20%|██        | 2/10 [00:14<00:51,  6.39s/sample]
#
# QFIM samples for both kept states (L=24):  30%|███       | 3/10 [00:16<00:30,  4.41s/sample]
#
# QFIM samples for both kept states (L=24):  40%|████      | 4/10 [00:18<00:20,  3.48s/sample]
#
# QFIM samples for both kept states (L=24):  50%|█████     | 5/10 [00:20<00:15,  3.01s/sample]
#
# QFIM samples for both kept states (L=24):  60%|██████    | 6/10 [00:22<00:10,  2.69s/sample]
#
# QFIM samples for both kept states (L=24):  70%|███████   | 7/10 [00:25<00:07,  2.51s/sample]
#
# QFIM samples for both kept states (L=24):  80%|████████  | 8/10 [00:27<00:04,  2.39s/sample]
#
# QFIM samples for both kept states (L=24):  90%|█████████ | 9/10 [00:29<00:02,  2.32s/sample]
#
# QFIM samples for both kept states (L=24): 100%|██████████| 10/10 [00:31<00:00,  2.26s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  71%|███████   | 12/17 [01:59<01:38, 19.73s/layer]
#
# QFIM samples for both kept states (L=28):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=28):  10%|█         | 1/10 [00:15<02:15, 15.10s/sample]
#
# QFIM samples for both kept states (L=28):  20%|██        | 2/10 [00:17<01:03,  7.91s/sample]
#
# QFIM samples for both kept states (L=28):  30%|███       | 3/10 [00:20<00:39,  5.63s/sample]
#
# QFIM samples for both kept states (L=28):  40%|████      | 4/10 [00:23<00:27,  4.56s/sample]
#
# QFIM samples for both kept states (L=28):  50%|█████     | 5/10 [00:26<00:19,  3.96s/sample]
#
# QFIM samples for both kept states (L=28):  60%|██████    | 6/10 [00:29<00:14,  3.60s/sample]
#
# QFIM samples for both kept states (L=28):  70%|███████   | 7/10 [00:32<00:10,  3.36s/sample]
#
# QFIM samples for both kept states (L=28):  80%|████████  | 8/10 [00:35<00:06,  3.20s/sample]
#
# QFIM samples for both kept states (L=28):  90%|█████████ | 9/10 [00:38<00:03,  3.13s/sample]
#
# QFIM samples for both kept states (L=28): 100%|██████████| 10/10 [00:41<00:00,  3.07s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  76%|███████▋  | 13/17 [02:40<01:45, 26.31s/layer]
#
# QFIM samples for both kept states (L=32):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=32):  10%|█         | 1/10 [00:17<02:35, 17.23s/sample]
#
# QFIM samples for both kept states (L=32):  20%|██        | 2/10 [00:21<01:14,  9.37s/sample]
#
# QFIM samples for both kept states (L=32):  30%|███       | 3/10 [00:24<00:48,  6.86s/sample]
#
# QFIM samples for both kept states (L=32):  40%|████      | 4/10 [00:28<00:34,  5.71s/sample]
#
# QFIM samples for both kept states (L=32):  50%|█████     | 5/10 [00:32<00:25,  5.02s/sample]
#
# QFIM samples for both kept states (L=32):  60%|██████    | 6/10 [00:36<00:18,  4.60s/sample]
#
# QFIM samples for both kept states (L=32):  70%|███████   | 7/10 [00:40<00:13,  4.39s/sample]
#
# QFIM samples for both kept states (L=32):  80%|████████  | 8/10 [00:44<00:08,  4.16s/sample]
#
# QFIM samples for both kept states (L=32):  90%|█████████ | 9/10 [00:47<00:04,  4.05s/sample]
#
# QFIM samples for both kept states (L=32): 100%|██████████| 10/10 [00:51<00:00,  3.97s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  82%|████████▏ | 14/17 [03:32<01:42, 34.06s/layer]
#
# QFIM samples for both kept states (L=36):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=36):  10%|█         | 1/10 [00:20<03:00, 20.11s/sample]
#
# QFIM samples for both kept states (L=36):  20%|██        | 2/10 [00:24<01:28, 11.12s/sample]
#
# QFIM samples for both kept states (L=36):  30%|███       | 3/10 [00:29<00:57,  8.21s/sample]
#
# QFIM samples for both kept states (L=36):  40%|████      | 4/10 [00:34<00:41,  6.93s/sample]
#
# QFIM samples for both kept states (L=36):  50%|█████     | 5/10 [00:39<00:30,  6.19s/sample]
#
# QFIM samples for both kept states (L=36):  60%|██████    | 6/10 [00:44<00:22,  5.63s/sample]
#
# QFIM samples for both kept states (L=36):  70%|███████   | 7/10 [00:48<00:16,  5.35s/sample]
#
# QFIM samples for both kept states (L=36):  80%|████████  | 8/10 [00:53<00:10,  5.18s/sample]
#
# QFIM samples for both kept states (L=36):  90%|█████████ | 9/10 [00:58<00:05,  5.08s/sample]
#
# QFIM samples for both kept states (L=36): 100%|██████████| 10/10 [01:03<00:00,  4.99s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  88%|████████▊ | 15/17 [04:36<01:25, 42.97s/layer]
#
# QFIM samples for both kept states (L=40):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=40):  10%|█         | 1/10 [00:22<03:26, 22.95s/sample]
#
# QFIM samples for both kept states (L=40):  20%|██        | 2/10 [00:28<01:42, 12.83s/sample]
#
# QFIM samples for both kept states (L=40):  30%|███       | 3/10 [00:34<01:07,  9.66s/sample]
#
# QFIM samples for both kept states (L=40):  40%|████      | 4/10 [00:40<00:48,  8.13s/sample]
#
# QFIM samples for both kept states (L=40):  50%|█████     | 5/10 [00:46<00:37,  7.40s/sample]
#
# QFIM samples for both kept states (L=40):  60%|██████    | 6/10 [00:52<00:27,  6.88s/sample]
#
# QFIM samples for both kept states (L=40):  70%|███████   | 7/10 [00:58<00:19,  6.58s/sample]
#
# QFIM samples for both kept states (L=40):  80%|████████  | 8/10 [01:04<00:12,  6.38s/sample]
#
# QFIM samples for both kept states (L=40):  90%|█████████ | 9/10 [01:10<00:06,  6.26s/sample]
#
# QFIM samples for both kept states (L=40): 100%|██████████| 10/10 [01:16<00:00,  6.17s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)):  94%|█████████▍| 16/17 [05:52<00:53, 53.07s/layer]
#
# QFIM samples for both kept states (L=44):   0%|          | 0/10 [00:00<?, ?sample/s]
#
# QFIM samples for both kept states (L=44):  10%|█         | 1/10 [00:26<03:58, 26.47s/sample]
#
# QFIM samples for both kept states (L=44):  20%|██        | 2/10 [00:33<01:59, 14.94s/sample]
#
# QFIM samples for both kept states (L=44):  30%|███       | 3/10 [00:40<01:20, 11.46s/sample]
#
# QFIM samples for both kept states (L=44):  40%|████      | 4/10 [00:47<00:58,  9.78s/sample]
#
# QFIM samples for both kept states (L=44):  50%|█████     | 5/10 [00:55<00:44,  8.84s/sample]
#
# QFIM samples for both kept states (L=44):  60%|██████    | 6/10 [01:02<00:33,  8.29s/sample]
#
# QFIM samples for both kept states (L=44):  70%|███████   | 7/10 [01:09<00:23,  7.92s/sample]
#
# QFIM samples for both kept states (L=44):  80%|████████  | 8/10 [01:16<00:15,  7.70s/sample]
#
# QFIM samples for both kept states (L=44):  90%|█████████ | 9/10 [01:23<00:07,  7.56s/sample]
#
# QFIM samples for both kept states (L=44): 100%|██████████| 10/10 [01:30<00:00,  7.39s/sample]
#
#
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)): 100%|██████████| 17/17 [07:24<00:00, 64.54s/layer]
# Layers (QFIM; keep=(0,1,2,3) and keep=(0,1,2,3,4)): 100%|██████████| 17/17 [07:24<00:00, 26.13s/layer]

# %%
# !python src\dpqc\DPQC_overparam_reset_visualize.py --h-param 0.1
