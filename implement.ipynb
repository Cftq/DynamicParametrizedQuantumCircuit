# %%
# !python src/dpqc/DPQC_overparam_compute.py

# %%
# !python src/unitary_pqc/unitary_pqc_overparam_compute.py
# Out:
# Layers (VQE):   0%|          | 0/7 [00:00<?, ?layer/s]
#
# Runs (L=1):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=1):  10%|█         | 1/10 [00:05<00:52,  5.81s/run]
#
# Runs (L=1):  20%|██        | 2/10 [00:11<00:45,  5.72s/run]
#
# Runs (L=1):  30%|███       | 3/10 [00:17<00:40,  5.77s/run]
#
# Runs (L=1):  40%|████      | 4/10 [00:23<00:36,  6.00s/run]
#
# Runs (L=1):  50%|█████     | 5/10 [00:29<00:29,  5.92s/run]
#
# Runs (L=1):  60%|██████    | 6/10 [00:35<00:23,  5.98s/run]
#
# Runs (L=1):  70%|███████   | 7/10 [00:41<00:17,  5.85s/run]
#
# Runs (L=1):  80%|████████  | 8/10 [00:47<00:11,  5.91s/run]
#
# Runs (L=1):  90%|█████████ | 9/10 [00:53<00:05,  5.90s/run]
#
# Runs (L=1): 100%|██████████| 10/10 [00:58<00:00,  5.91s/run]
#
#
# Layers (VQE):  14%|█▍        | 1/7 [00:59<05:55, 59.26s/layer]
#
# Runs (L=2):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=2):  10%|█         | 1/10 [00:12<01:52, 12.52s/run]
#
# Runs (L=2):  20%|██        | 2/10 [00:22<01:30, 11.27s/run]
#
# Runs (L=2):  30%|███       | 3/10 [00:33<01:16, 10.99s/run]
#
# Runs (L=2):  40%|████      | 4/10 [00:43<01:04, 10.67s/run]
#
# Runs (L=2):  50%|█████     | 5/10 [00:53<00:52, 10.50s/run]
#
# Runs (L=2):  60%|██████    | 6/10 [01:04<00:41, 10.42s/run]
#
# Runs (L=2):  70%|███████   | 7/10 [01:14<00:31, 10.38s/run]
#
# Runs (L=2):  80%|████████  | 8/10 [01:24<00:20, 10.35s/run]
#
# Runs (L=2):  90%|█████████ | 9/10 [01:35<00:10, 10.31s/run]
#
# Runs (L=2): 100%|██████████| 10/10 [01:45<00:00, 10.26s/run]
#
#
# Layers (VQE):  29%|██▊       | 2/7 [02:44<07:11, 86.35s/layer]
#
# Runs (L=3):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=3):  10%|█         | 1/10 [00:17<02:34, 17.15s/run]
#
# Runs (L=3):  20%|██        | 2/10 [00:32<02:08, 16.03s/run]
#
# Runs (L=3):  30%|███       | 3/10 [00:47<01:50, 15.76s/run]
#
# Runs (L=3):  40%|████      | 4/10 [01:03<01:33, 15.56s/run]
#
# Runs (L=3):  50%|█████     | 5/10 [01:18<01:17, 15.43s/run]
#
# Runs (L=3):  60%|██████    | 6/10 [01:33<01:01, 15.28s/run]
#
# Runs (L=3):  70%|███████   | 7/10 [01:48<00:45, 15.29s/run]
#
# Runs (L=3):  80%|████████  | 8/10 [02:03<00:30, 15.25s/run]
#
# Runs (L=3):  90%|█████████ | 9/10 [02:19<00:15, 15.27s/run]
#
# Runs (L=3): 100%|██████████| 10/10 [02:33<00:00, 15.16s/run]
#
#
# Layers (VQE):  43%|████▎     | 3/7 [05:18<07:49, 117.31s/layer]
#
# Runs (L=4):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=4):  10%|█         | 1/10 [00:22<03:22, 22.45s/run]
#
# Runs (L=4):  20%|██        | 2/10 [00:42<02:47, 20.92s/run]
#
# Runs (L=4):  30%|███       | 3/10 [01:02<02:25, 20.72s/run]
#
# Runs (L=4):  40%|████      | 4/10 [01:23<02:03, 20.58s/run]
#
# Runs (L=4):  50%|█████     | 5/10 [01:42<01:41, 20.22s/run]
#
# Runs (L=4):  60%|██████    | 6/10 [02:02<01:20, 20.09s/run]
#
# Runs (L=4):  70%|███████   | 7/10 [02:22<01:00, 20.01s/run]
#
# Runs (L=4):  80%|████████  | 8/10 [02:42<00:39, 19.95s/run]
#
# Runs (L=4):  90%|█████████ | 9/10 [03:02<00:19, 19.90s/run]
#
# Runs (L=4): 100%|██████████| 10/10 [03:21<00:00, 19.89s/run]
#
#
# Layers (VQE):  57%|█████▋    | 4/7 [08:40<07:32, 150.76s/layer]
#
# Runs (L=5):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=5):  10%|█         | 1/10 [00:27<04:07, 27.48s/run]
#
# Runs (L=5):  20%|██        | 2/10 [00:52<03:27, 25.90s/run]
#
# Runs (L=5):  30%|███       | 3/10 [01:18<03:00, 25.82s/run]
#
# Runs (L=5):  40%|████      | 4/10 [01:43<02:33, 25.57s/run]
#
# Runs (L=5):  50%|█████     | 5/10 [02:08<02:07, 25.51s/run]
#
# Runs (L=5):  60%|██████    | 6/10 [02:34<01:42, 25.51s/run]
#
# Runs (L=5):  70%|███████   | 7/10 [02:59<01:16, 25.53s/run]
#
# Runs (L=5):  80%|████████  | 8/10 [03:25<00:50, 25.48s/run]
#
# Runs (L=5):  90%|█████████ | 9/10 [03:50<00:25, 25.62s/run]
#
# Runs (L=5): 100%|██████████| 10/10 [04:16<00:00, 25.53s/run]
#
#
# Layers (VQE):  71%|███████▏  | 5/7 [12:57<06:17, 188.87s/layer]
#
# Runs (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=6):  10%|█         | 1/10 [00:32<04:54, 32.70s/run]
#
# Runs (L=6):  20%|██        | 2/10 [01:02<04:10, 31.26s/run]
#
# Runs (L=6):  30%|███       | 3/10 [01:33<03:38, 31.16s/run]
#
# Runs (L=6):  40%|████      | 4/10 [02:04<03:05, 30.93s/run]
#
# Runs (L=6):  50%|█████     | 5/10 [02:35<02:34, 30.86s/run]
#
# Runs (L=6):  60%|██████    | 6/10 [03:05<02:02, 30.68s/run]
#
# Runs (L=6):  70%|███████   | 7/10 [03:35<01:31, 30.50s/run]
#
# Runs (L=6):  80%|████████  | 8/10 [04:06<01:01, 30.56s/run]
#
# Runs (L=6):  90%|█████████ | 9/10 [04:37<00:30, 30.68s/run]
#
# Runs (L=6): 100%|██████████| 10/10 [05:08<00:00, 30.68s/run]
#
#
# Layers (VQE):  86%|████████▌ | 6/7 [18:05<03:49, 229.45s/layer]
#
# Runs (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
# Runs (L=7):  10%|█         | 1/10 [00:37<05:34, 37.22s/run]
#
# Runs (L=7):  20%|██        | 2/10 [01:11<04:46, 35.78s/run]
#
# Runs (L=7):  30%|███       | 3/10 [01:46<04:06, 35.25s/run]
#
# Runs (L=7):  40%|████      | 4/10 [02:21<03:29, 34.91s/run]
#
# Runs (L=7):  50%|█████     | 5/10 [02:55<02:54, 34.81s/run]
#
# Runs (L=7):  60%|██████    | 6/10 [03:30<02:19, 34.77s/run]
#
# Runs (L=7):  70%|███████   | 7/10 [04:04<01:44, 34.72s/run]
#
# Runs (L=7):  80%|████████  | 8/10 [04:39<01:09, 34.54s/run]
#
# Runs (L=7):  90%|█████████ | 9/10 [05:13<00:34, 34.64s/run]
#
# Runs (L=7): 100%|██████████| 10/10 [05:47<00:00, 34.36s/run]
#
#
# Layers (VQE): 100%|██████████| 7/7 [23:53<00:00, 268.16s/layer]
# Layers (VQE): 100%|██████████| 7/7 [23:53<00:00, 204.76s/layer]
#
# Layers (QFIM):   0%|          | 0/7 [00:00<?, ?layer/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   1%|          | 1/100 [00:02<04:43,  2.87s/sample]
#
# Reduced QFIM samples (rank+eigs) (L=1):   2%|▏         | 2/100 [00:02<02:03,  1.26s/sample]
#
# Reduced QFIM samples (rank+eigs) (L=1):   3%|▎         | 3/100 [00:03<01:21,  1.19sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   4%|▍         | 4/100 [00:03<00:55,  1.74sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   5%|▌         | 5/100 [00:03<00:38,  2.44sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   6%|▌         | 6/100 [00:03<00:28,  3.24sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   7%|▋         | 7/100 [00:03<00:22,  4.05sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   8%|▊         | 8/100 [00:03<00:19,  4.77sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):   9%|▉         | 9/100 [00:04<00:16,  5.48sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  10%|█         | 10/100 [00:04<00:14,  6.21sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  11%|█         | 11/100 [00:04<00:13,  6.84sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  12%|█▏        | 12/100 [00:04<00:12,  7.01sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  13%|█▎        | 13/100 [00:04<00:11,  7.39sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  14%|█▍        | 14/100 [00:04<00:11,  7.61sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  15%|█▌        | 15/100 [00:04<00:10,  7.92sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  16%|█▌        | 16/100 [00:05<00:16,  5.14sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  17%|█▋        | 17/100 [00:05<00:14,  5.71sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  18%|█▊        | 18/100 [00:05<00:12,  6.35sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  19%|█▉        | 19/100 [00:05<00:12,  6.24sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  20%|██        | 20/100 [00:05<00:12,  6.27sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  21%|██        | 21/100 [00:05<00:11,  6.86sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  22%|██▏       | 22/100 [00:06<00:11,  6.83sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  23%|██▎       | 23/100 [00:06<00:11,  6.61sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  24%|██▍       | 24/100 [00:06<00:10,  7.00sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  25%|██▌       | 25/100 [00:06<00:10,  7.41sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  26%|██▌       | 26/100 [00:06<00:09,  7.66sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  27%|██▋       | 27/100 [00:06<00:09,  7.71sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  28%|██▊       | 28/100 [00:06<00:09,  7.63sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  29%|██▉       | 29/100 [00:07<00:14,  4.88sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):
ample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  82%|████████▏ | 82/100 [00:14<00:02,  7.69sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  83%|████████▎ | 83/100 [00:14<00:02,  7.65sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  84%|████████▍ | 84/100 [00:15<00:03,  5.25sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  85%|████████▌ | 85/100 [00:15<00:02,  5.94sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  86%|████████▌ | 86/100 [00:15<00:02,  6.54sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  87%|████████▋ | 87/100 [00:15<00:01,  7.06sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  88%|████████▊ | 88/100 [00:15<00:01,  7.12sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  89%|████████▉ | 89/100 [00:15<00:01,  7.54sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  90%|█████████ | 90/100 [00:15<00:01,  7.49sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  91%|█████████ | 91/100 [00:15<00:01,  7.46sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  92%|█████████▏| 92/100 [00:16<00:01,  7.22sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  93%|█████████▎| 93/100 [00:16<00:00,  7.68sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  94%|█████████▍| 94/100 [00:16<00:00,  7.81sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  95%|█████████▌| 95/100 [00:16<00:00,  8.06sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  96%|█████████▌| 96/100 [00:16<00:00,  7.71sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  97%|█████████▋| 97/100 [00:16<00:00,  5.12sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  98%|█████████▊| 98/100 [00:17<00:00,  5.71sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1):  99%|█████████▉| 99/100 [00:17<00:00,  6.27sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=1): 100%|██████████| 100/100 [00:17<00:00,  6.58sample/s]
#
#
#
# Reduced HS samples (rank+eigs) (L=1):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   1%|          | 1/100 [00:01<02:51,  1.73s/sample]
#
# Reduced HS samples (rank+eigs) (L=1):   2%|▏         | 2/100 [00:01<01:17,  1.27sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   3%|▎         | 3/100 [00:01<00:47,  2.04sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   4%|▍         | 4/100 [00:02<00:33,  2.90sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   5%|▌         | 5/100 [00:02<00:25,  3.80sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   6%|▌         | 6/100 [00:02<00:20,  4.55sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   7%|▋         | 7/100 [00:02<00:24,  3.78sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   8%|▊         | 8/100 [00:02<00:20,  4.48sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):   9%|▉         | 9/100 [00:02<00:17,  5.15sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  10%|█         | 10/100 [00:03<00:15,  5.83sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  11%|█         | 11/100 [00:03<00:13,  6.41sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  12%|█▏        | 12/100 [00:03<00:12,  6.85sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  13%|█▎        | 13/100 [00:03<00:12,  7.13sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  14%|█▍        | 14/100 [00:03<00:11,  7.60sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  15%|█▌        | 15/100 [00:03<00:10,  7.97sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  16%|█▌        | 16/100 [00:03<00:10,  8.15sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  17%|█▋        | 17/100 [00:03<00:10,  7.98sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  18%|█▊        | 18/100 [00:04<00:10,  7.84sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  19%|█▉        | 19/100 [00:04<00:10,  7.97sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  20%|██        | 20/100 [00:04<00:09,  8.23sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  21%|██        | 21/100 [00:04<00:15,  5.21sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  22%|██▏       | 22/100 [00:04<00:13,  5.92sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  23%|██▎       | 23/100 [00:04<00:12,  6.37sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  24%|██▍       | 24/100 [00:05<00:11,  6.86sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  25%|██▌       | 25/100 [00:05<00:10,  7.41sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  26%|██▌       | 26/100 [00:05<00:09,  7.67sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  27%|██▋       | 27/100 [00:05<00:09,  7.67sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  28%|██▊       | 28/100 [00:05<00:09,  7.77sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  29%|██▉       | 29/100 [00:05<00:09,  7.38sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  30%|███       | 30/100 [00:05<00:09,  7.26sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  31%|███       | 31/100 [00:05<00:09,  7.22sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):
ample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  84%|████████▍ | 84/100 [00:13<00:02,  7.14sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  85%|████████▌ | 85/100 [00:13<00:01,  7.54sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  86%|████████▌ | 86/100 [00:13<00:01,  7.88sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  87%|████████▋ | 87/100 [00:13<00:01,  8.02sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  88%|████████▊ | 88/100 [00:14<00:01,  7.41sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  89%|████████▉ | 89/100 [00:14<00:01,  7.59sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  90%|█████████ | 90/100 [00:14<00:01,  7.87sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  91%|█████████ | 91/100 [00:14<00:01,  8.18sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  92%|█████████▏| 92/100 [00:14<00:01,  5.10sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  93%|█████████▎| 93/100 [00:14<00:01,  5.66sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  94%|█████████▍| 94/100 [00:15<00:00,  6.23sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  95%|█████████▌| 95/100 [00:15<00:00,  6.45sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  96%|█████████▌| 96/100 [00:15<00:00,  6.82sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  97%|█████████▋| 97/100 [00:15<00:00,  7.10sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  98%|█████████▊| 98/100 [00:15<00:00,  7.39sample/s]
#
# Reduced HS samples (rank+eigs) (L=1):  99%|█████████▉| 99/100 [00:15<00:00,  7.62sample/s]
#
# Reduced HS samples (rank+eigs) (L=1): 100%|██████████| 100/100 [00:15<00:00,  7.81sample/s]
#
#
#
# Observable tangent kernel samples (L=1):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Observable tangent kernel samples (L=1):   1%|          | 1/100 [00:01<02:44,  1.66s/sample]
#
# Observable tangent kernel samples (L=1):  22%|██▏       | 22/100 [00:01<00:04, 17.17sample/s]
#
# Observable tangent kernel samples (L=1):  44%|████▍     | 44/100 [00:01<00:01, 37.62sample/s]
#
# Observable tangent kernel samples (L=1):  65%|██████▌   | 65/100 [00:01<00:00, 59.08sample/s]
#
# Observable tangent kernel samples (L=1):  86%|████████▌ | 86/100 [00:02<00:00, 81.86sample/s]
#
#
#
# Energy Hessian samples (rank+eigs) (L=1):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):   1%|          | 1/100 [00:03<06:03,  3.67s/sample]
#
# Energy Hessian samples (rank+eigs) (L=1):   7%|▋         | 7/100 [00:03<00:37,  2.51sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  14%|█▍        | 14/100 [00:03<00:14,  5.90sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  21%|██        | 21/100 [00:03<00:07, 10.11sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  27%|██▋       | 27/100 [00:04<00:05, 14.41sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  34%|███▍      | 34/100 [00:04<00:03, 20.28sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  41%|████      | 41/100 [00:04<00:02, 26.56sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  48%|████▊     | 48/100 [00:04<00:01, 32.91sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  55%|█████▌    | 55/100 [00:04<00:01, 38.35sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  62%|██████▏   | 62/100 [00:04<00:00, 44.15sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  69%|██████▉   | 69/100 [00:04<00:00, 48.40sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  76%|███████▌  | 76/100 [00:04<00:00, 52.33sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  83%|████████▎ | 83/100 [00:04<00:00, 55.77sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  90%|█████████ | 90/100 [00:05<00:00, 58.23sample/s]
#
# Energy Hessian samples (rank+eigs) (L=1):  97%|█████████▋| 97/100 [00:05<00:00, 60.29sample/s]
#
#
#
# Pure(full) QFIM samples (rank+eigs) (L=1):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Pure(full) QFIM samples (rank+eigs) (L=1):   1%|          | 1/100 [00:00<01:33,  1.06sample/s]
#
#
# Layers (QFIM):  14%|█▍        | 1/7 [00:41<04:10, 41.80s/layer]
#
# Reduced QFIM samples (rank+eigs) (L=2):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   1%|          | 1/100 [00:03<06:34,  3.98s/sample]
#
# Reduced QFIM samples (rank+eigs) (L=2):   2%|▏         | 2/100 [00:04<02:53,  1.78s/sample]
#
# Reduced QFIM samples (rank+eigs) (L=2):   3%|▎         | 3/100 [00:04<01:44,  1.08s/sample]
#
# Reduced QFIM samples (rank+eigs) (L=2):   4%|▍         | 4/100 [00:04<01:12,  1.33sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   5%|▌         | 5/100 [00:04<00:53,  1.77sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   6%|▌         | 6/100 [00:05<00:42,  2.20sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   7%|▋         | 7/100 [00:05<00:35,  2.60sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   8%|▊         | 8/100 [00:05<00:39,  2.33sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):   9%|▉         | 9/100 [00:06<00:34,  2.66sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  10%|█         | 10/100 [00:06<00:29,  3.02sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  11%|█         | 11/100 [00:06<00:27,  3.22sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  12%|█▏        | 12/100 [00:06<00:26,  3.35sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  13%|█▎        | 13/100 [00:07<00:25,  3.42sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  14%|█▍        | 14/100 [00:07<00:23,  3.58sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  15%|█▌        | 15/100 [00:07<00:23,  3.66sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  16%|█▌        | 16/100 [00:07<00:21,  3.84sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  17%|█▋        | 17/100 [00:08<00:27,  2.99sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  18%|█▊        | 18/100 [00:08<00:25,  3.22sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  19%|█▉        | 19/100 [00:08<00:23,  3.48sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  20%|██        | 20/100 [00:09<00:22,  3.50sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  21%|██        | 21/100 [00:09<00:21,  3.64sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  22%|██▏       | 22/100 [00:09<00:20,  3.86sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  23%|██▎       | 23/100 [00:09<00:19,  3.99sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  24%|██▍       | 24/100 [00:10<00:18,  4.10sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  25%|██▌       | 25/100 [00:10<00:26,  2.85sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  26%|██▌       | 26/100 [00:11<00:23,  3.19sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  27%|██▋       | 27/100 [00:11<00:22,  3.24sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  28%|██▊       | 28/100 [00:11<00:21,  3.42sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  29%|██▉       | 29/100 [00:11<00:19,  3.67sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  30%|███       | 30/100 [00:12<00:18,  3.86sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  31%|███       | 31/100 [00:12<00:17,  3.98sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  32%|███▏      | 32/100 [00:12<00:17,  3.94sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  33%|███▎      | 33/100 [00:13<00:22,  3.03sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  34%|███▍      | 34/100 [00:13<00:21,  3.11sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):
ample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  87%|████████▋ | 87/100 [00:28<00:03,  3.75sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  88%|████████▊ | 88/100 [00:28<00:03,  3.79sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  89%|████████▉ | 89/100 [00:28<00:02,  3.76sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  90%|█████████ | 90/100 [00:29<00:02,  3.87sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  91%|█████████ | 91/100 [00:29<00:02,  3.05sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  92%|█████████▏| 92/100 [00:29<00:02,  3.30sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  93%|█████████▎| 93/100 [00:30<00:01,  3.55sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  94%|█████████▍| 94/100 [00:30<00:01,  3.61sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  95%|█████████▌| 95/100 [00:30<00:01,  3.67sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  96%|█████████▌| 96/100 [00:30<00:01,  3.80sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  97%|█████████▋| 97/100 [00:31<00:00,  3.79sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  98%|█████████▊| 98/100 [00:31<00:00,  3.94sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2):  99%|█████████▉| 99/100 [00:31<00:00,  2.92sample/s]
#
# Reduced QFIM samples (rank+eigs) (L=2): 100%|██████████| 100/100 [00:32<00:00,  3.24sample/s]
#
#
#
# Reduced HS samples (rank+eigs) (L=2):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   1%|          | 1/100 [00:02<04:35,  2.79s/sample]
#
# Reduced HS samples (rank+eigs) (L=2):   2%|▏         | 2/100 [00:03<02:05,  1.28s/sample]
#
# Reduced HS samples (rank+eigs) (L=2):   3%|▎         | 3/100 [00:03<01:18,  1.24sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   4%|▍         | 4/100 [00:03<01:09,  1.38sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   5%|▌         | 5/100 [00:04<00:55,  1.73sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   6%|▌         | 6/100 [00:04<00:43,  2.17sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   7%|▋         | 7/100 [00:04<00:36,  2.55sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   8%|▊         | 8/100 [00:04<00:32,  2.82sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):   9%|▉         | 9/100 [00:05<00:29,  3.09sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  10%|█         | 10/100 [00:05<00:28,  3.14sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  11%|█         | 11/100 [00:05<00:26,  3.42sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  12%|█▏        | 12/100 [00:05<00:24,  3.66sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  13%|█▎        | 13/100 [00:06<00:30,  2.85sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  14%|█▍        | 14/100 [00:06<00:28,  3.07sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  15%|█▌        | 15/100 [00:07<00:26,  3.23sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  16%|█▌        | 16/100 [00:07<00:24,  3.45sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  17%|█▋        | 17/100 [00:07<00:22,  3.65sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  18%|█▊        | 18/100 [00:07<00:21,  3.83sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  19%|█▉        | 19/100 [00:08<00:21,  3.83sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  20%|██        | 20/100 [00:08<00:21,  3.78sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  21%|██        | 21/100 [00:08<00:28,  2.76sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  22%|██▏       | 22/100 [00:09<00:26,  2.98sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  23%|██▎       | 23/100 [00:09<00:23,  3.21sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  24%|██▍       | 24/100 [00:09<00:22,  3.42sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  25%|██▌       | 25/100 [00:09<00:20,  3.63sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  26%|██▌       | 26/100 [00:10<00:19,  3.82sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  27%|██▋       | 27/100 [00:10<00:18,  3.87sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  28%|██▊       | 28/100 [00:10<00:18,  3.81sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  29%|██▉       | 29/100 [00:10<00:18,  3.94sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  30%|███       | 30/100 [00:11<00:24,  2.85sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  31%|███       | 31/100 [00:11<00:22,  3.10sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  32%|███▏      | 32/100 [00:11<00:20,  3.26sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  33%|███▎      | 33/100 [00:12<00:19,  3.52sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  34%|███▍      | 34/100 [00:12<00:17,  3.70sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):
ample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  87%|████████▋ | 87/100 [00:27<00:03,  3.81sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  88%|████████▊ | 88/100 [00:27<00:04,  2.82sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  89%|████████▉ | 89/100 [00:28<00:03,  3.04sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  90%|█████████ | 90/100 [00:28<00:03,  3.29sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  91%|█████████ | 91/100 [00:28<00:02,  3.49sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  92%|█████████▏| 92/100 [00:28<00:02,  3.58sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  93%|█████████▎| 93/100 [00:29<00:01,  3.70sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  94%|█████████▍| 94/100 [00:29<00:01,  3.76sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  95%|█████████▌| 95/100 [00:29<00:01,  3.88sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  96%|█████████▌| 96/100 [00:30<00:01,  2.85sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  97%|█████████▋| 97/100 [00:30<00:00,  3.00sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  98%|█████████▊| 98/100 [00:30<00:00,  3.27sample/s]
#
# Reduced HS samples (rank+eigs) (L=2):  99%|█████████▉| 99/100 [00:30<00:00,  3.48sample/s]
#
# Reduced HS samples (rank+eigs) (L=2): 100%|██████████| 100/100 [00:31<00:00,  3.63sample/s]
#
#
#
# Observable tangent kernel samples (L=2):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Observable tangent kernel samples (L=2):   1%|          | 1/100 [00:01<03:06,  1.89s/sample]
#
# Observable tangent kernel samples (L=2):  14%|█▍        | 14/100 [00:01<00:08,  9.59sample/s]
#
# Observable tangent kernel samples (L=2):  26%|██▌       | 26/100 [00:02<00:03, 19.56sample/s]
#
# Observable tangent kernel samples (L=2):  39%|███▉      | 39/100 [00:02<00:01, 32.04sample/s]
#
# Observable tangent kernel samples (L=2):  50%|█████     | 50/100 [00:02<00:01, 42.90sample/s]
#
# Observable tangent kernel samples (L=2):  62%|██████▏   | 62/100 [00:02<00:00, 54.99sample/s]
#
# Observable tangent kernel samples (L=2):  75%|███████▌  | 75/100 [00:02<00:00, 68.36sample/s]
#
# Observable tangent kernel samples (L=2):  88%|████████▊ | 88/100 [00:02<00:00, 80.90sample/s]
#
# Observable tangent kernel samples (L=2): 100%|██████████| 100/100 [00:02<00:00, 89.52sample/s]
#
#
#
# Energy Hessian samples (rank+eigs) (L=2):   0%|          | 0/100 [00:00<?, ?sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):   1%|          | 1/100 [00:04<07:28,  4.53s/sample]
#
# Energy Hessian samples (rank+eigs) (L=2):   4%|▍         | 4/100 [00:04<01:25,  1.12sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):   7%|▋         | 7/100 [00:04<00:41,  2.27sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):  10%|█         | 10/100 [00:04<00:24,  3.71sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):  13%|█▎        | 13/100 [00:05<00:16,  5.41sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):  16%|█▌        | 16/100 [00:05<00:11,  7.32sample/s]
#
# Energy Hessian samples (rank+eigs) (L=2):  19%|█▉        | 19/100 [00:05<00:08,  9.38sample/s]
#
# ...
#
#
# QFIM-gradient scatter data (L=5): 100%|██████████| 10/10 [00:08<00:00,  1.37run/s]
#
#
#
#
# Iterations (L=5):  67%|██████▋   | 4/6 [00:33<00:16,  8.37s/iter]
#
#
# QFIM-gradient scatter data (L=5):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=5):  10%|█         | 1/10 [00:02<00:25,  2.86s/run]
#
#
# QFIM-gradient scatter data (L=5):  20%|██        | 2/10 [00:03<00:11,  1.48s/run]
#
#
# QFIM-gradient scatter data (L=5):  30%|███       | 3/10 [00:03<00:07,  1.02s/run]
#
#
# QFIM-gradient scatter data (L=5):  40%|████      | 4/10 [00:04<00:04,  1.24run/s]
#
#
# QFIM-gradient scatter data (L=5):  50%|█████     | 5/10 [00:04<00:03,  1.43run/s]
#
#
# QFIM-gradient scatter data (L=5):  60%|██████    | 6/10 [00:05<00:02,  1.59run/s]
#
#
# QFIM-gradient scatter data (L=5):  70%|███████   | 7/10 [00:05<00:01,  1.72run/s]
#
#
# QFIM-gradient scatter data (L=5):  80%|████████  | 8/10 [00:06<00:01,  1.81run/s]
#
#
# QFIM-gradient scatter data (L=5):  90%|█████████ | 9/10 [00:06<00:00,  1.89run/s]
#
#
# QFIM-gradient scatter data (L=5): 100%|██████████| 10/10 [00:07<00:00,  1.93run/s]
#
#
#
#
# Iterations (L=5):  83%|████████▎ | 5/6 [00:40<00:07,  7.98s/iter]
#
#
# QFIM-gradient scatter data (L=5):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=5):  10%|█         | 1/10 [00:03<00:33,  3.75s/run]
#
#
# QFIM-gradient scatter data (L=5):  20%|██        | 2/10 [00:04<00:14,  1.83s/run]
#
#
# QFIM-gradient scatter data (L=5):  30%|███       | 3/10 [00:04<00:08,  1.21s/run]
#
#
# QFIM-gradient scatter data (L=5):  40%|████      | 4/10 [00:05<00:05,  1.06run/s]
#
#
# QFIM-gradient scatter data (L=5):  50%|█████     | 5/10 [00:05<00:03,  1.28run/s]
#
#
# QFIM-gradient scatter data (L=5):  60%|██████    | 6/10 [00:06<00:02,  1.43run/s]
#
#
# QFIM-gradient scatter data (L=5):  70%|███████   | 7/10 [00:06<00:01,  1.60run/s]
#
#
# QFIM-gradient scatter data (L=5):  80%|████████  | 8/10 [00:07<00:01,  1.71run/s]
#
#
# QFIM-gradient scatter data (L=5):  90%|█████████ | 9/10 [00:07<00:00,  1.77run/s]
#
#
# QFIM-gradient scatter data (L=5): 100%|██████████| 10/10 [00:08<00:00,  1.86run/s]
#
#
#
#
# Iterations (L=5): 100%|██████████| 6/6 [00:49<00:00,  8.08s/iter]
#
#
# QFIM eigenvalue-gradient scatter by layer/iteration:  71%|███████▏  | 5/7 [02:59<01:20, 40.21s/layer]
#
# Iterations (L=6):   0%|          | 0/6 [00:00<?, ?iter/s]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:04<00:37,  4.16s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:04<00:16,  2.08s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:05<00:09,  1.42s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:06<00:06,  1.11s/run]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:06<00:04,  1.08run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:07<00:03,  1.22run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:07<00:02,  1.33run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:08<00:01,  1.42run/s]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:09<00:00,  1.44run/s]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:09<00:00,  1.50run/s]
#
#
#
#
# Iterations (L=6):  17%|█▋        | 1/6 [00:09<00:48,  9.78s/iter]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:03<00:33,  3.69s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:04<00:15,  1.89s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:04<00:09,  1.31s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:05<00:06,  1.03s/run]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:06<00:04,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:06<00:03,  1.25run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:07<00:02,  1.35run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:08<00:01,  1.41run/s]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:08<00:00,  1.46run/s]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:10<00:00,  1.08run/s]
#
#
#
#
# Iterations (L=6):  33%|███▎      | 2/6 [00:19<00:40, 10.02s/iter]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:02<00:26,  2.94s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:03<00:12,  1.60s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:04<00:08,  1.15s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:04<00:05,  1.05run/s]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:05<00:04,  1.21run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:06<00:03,  1.32run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:06<00:02,  1.40run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:07<00:01,  1.47run/s]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:08<00:00,  1.05run/s]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:09<00:00,  1.16run/s]
#
#
#
#
# Iterations (L=6):  50%|█████     | 3/6 [00:29<00:29,  9.81s/iter]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:03<00:27,  3.07s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:03<00:13,  1.63s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:04<00:08,  1.17s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:04<00:05,  1.05run/s]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:05<00:04,  1.18run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:06<00:03,  1.25run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:06<00:02,  1.31run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:07<00:01,  1.41run/s]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:09<00:01,  1.00s/run]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:09<00:00,  1.11run/s]
#
#
#
#
# Iterations (L=6):  67%|██████▋   | 4/6 [00:39<00:19,  9.85s/iter]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:03<00:27,  3.03s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:03<00:13,  1.63s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:04<00:08,  1.18s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:04<00:05,  1.05run/s]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:05<00:04,  1.22run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:06<00:02,  1.33run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:06<00:02,  1.41run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:08<00:01,  1.02run/s]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:08<00:00,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:09<00:00,  1.22run/s]
#
#
#
#
# Iterations (L=6):  83%|████████▎ | 5/6 [00:49<00:09,  9.79s/iter]
#
#
# QFIM-gradient scatter data (L=6):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=6):  10%|█         | 1/10 [00:03<00:27,  3.08s/run]
#
#
# QFIM-gradient scatter data (L=6):  20%|██        | 2/10 [00:03<00:13,  1.65s/run]
#
#
# QFIM-gradient scatter data (L=6):  30%|███       | 3/10 [00:04<00:08,  1.20s/run]
#
#
# QFIM-gradient scatter data (L=6):  40%|████      | 4/10 [00:05<00:05,  1.03run/s]
#
#
# QFIM-gradient scatter data (L=6):  50%|█████     | 5/10 [00:05<00:04,  1.15run/s]
#
#
# QFIM-gradient scatter data (L=6):  60%|██████    | 6/10 [00:06<00:03,  1.25run/s]
#
#
# QFIM-gradient scatter data (L=6):  70%|███████   | 7/10 [00:06<00:02,  1.36run/s]
#
#
# QFIM-gradient scatter data (L=6):  80%|████████  | 8/10 [00:08<00:02,  1.00s/run]
#
#
# QFIM-gradient scatter data (L=6):  90%|█████████ | 9/10 [00:09<00:00,  1.10run/s]
#
#
# QFIM-gradient scatter data (L=6): 100%|██████████| 10/10 [00:09<00:00,  1.21run/s]
#
#
#
#
# Iterations (L=6): 100%|██████████| 6/6 [00:59<00:00,  9.84s/iter]
#
#
# QFIM eigenvalue-gradient scatter by layer/iteration:  86%|████████▌ | 6/7 [03:58<00:46, 46.62s/layer]
#
# Iterations (L=7):   0%|          | 0/6 [00:00<?, ?iter/s]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:03<00:31,  3.45s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:04<00:15,  1.89s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:04<00:09,  1.36s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:05<00:06,  1.10s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:06<00:04,  1.04run/s]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:07<00:03,  1.14run/s]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:08<00:03,  1.14s/run]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:02,  1.04s/run]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:10<00:00,  1.04run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:11<00:00,  1.12run/s]
#
#
#
#
# Iterations (L=7):  17%|█▋        | 1/6 [00:11<00:55, 11.17s/iter]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:03<00:27,  3.10s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:03<00:13,  1.70s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:04<00:08,  1.24s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:05<00:06,  1.06s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:06<00:06,  1.27s/run]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:07<00:04,  1.07s/run]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:08<00:02,  1.02run/s]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:01,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:09<00:00,  1.19run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:10<00:00,  1.20run/s]
#
#
#
#
# Iterations (L=7):  33%|███▎      | 2/6 [00:21<00:43, 10.88s/iter]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:03<00:28,  3.13s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:03<00:13,  1.71s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:04<00:08,  1.25s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:06<00:08,  1.40s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:06<00:05,  1.17s/run]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:07<00:04,  1.03s/run]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:08<00:02,  1.07run/s]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:01,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:09<00:00,  1.18run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:10<00:00,  1.23run/s]
#
#
#
#
# Iterations (L=7):  50%|█████     | 3/6 [00:32<00:32, 10.82s/iter]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:03<00:29,  3.25s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:04<00:18,  2.30s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:05<00:11,  1.59s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:06<00:07,  1.27s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:07<00:05,  1.07s/run]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:07<00:03,  1.04run/s]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:08<00:02,  1.12run/s]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:01,  1.19run/s]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:10<00:00,  1.24run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:10<00:00,  1.27run/s]
#
#
#
#
# Iterations (L=7):  67%|██████▋   | 4/6 [00:43<00:21, 10.83s/iter]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:04<00:39,  4.34s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:05<00:17,  2.18s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:05<00:10,  1.55s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:06<00:07,  1.25s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:07<00:05,  1.08s/run]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:08<00:03,  1.04run/s]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:08<00:02,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:01,  1.18run/s]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:10<00:00,  1.22run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:12<00:00,  1.10s/run]
#
#
#
#
# Iterations (L=7):  83%|████████▎ | 5/6 [00:55<00:11, 11.29s/iter]
#
#
# QFIM-gradient scatter data (L=7):   0%|          | 0/10 [00:00<?, ?run/s]
#
#
# QFIM-gradient scatter data (L=7):  10%|█         | 1/10 [00:03<00:28,  3.12s/run]
#
#
# QFIM-gradient scatter data (L=7):  20%|██        | 2/10 [00:03<00:14,  1.75s/run]
#
#
# QFIM-gradient scatter data (L=7):  30%|███       | 3/10 [00:04<00:09,  1.29s/run]
#
#
# QFIM-gradient scatter data (L=7):  40%|████      | 4/10 [00:05<00:06,  1.07s/run]
#
#
# QFIM-gradient scatter data (L=7):  50%|█████     | 5/10 [00:06<00:04,  1.05run/s]
#
#
# QFIM-gradient scatter data (L=7):  60%|██████    | 6/10 [00:06<00:03,  1.13run/s]
#
#
# QFIM-gradient scatter data (L=7):  70%|███████   | 7/10 [00:07<00:02,  1.20run/s]
#
#
# QFIM-gradient scatter data (L=7):  80%|████████  | 8/10 [00:09<00:02,  1.10s/run]
#
#
# QFIM-gradient scatter data (L=7):  90%|█████████ | 9/10 [00:10<00:00,  1.01run/s]
#
#
# QFIM-gradient scatter data (L=7): 100%|██████████| 10/10 [00:10<00:00,  1.11run/s]
#
#
#
#
# Iterations (L=7): 100%|██████████| 6/6 [01:06<00:00, 11.11s/iter]
#
#
# QFIM eigenvalue-gradient scatter by layer/iteration: 100%|██████████| 7/7 [05:05<00:00, 53.05s/layer]
# QFIM eigenvalue-gradient scatter by layer/iteration: 100%|██████████| 7/7 [05:05<00:00, 43.61s/layer]

# %%
# !python src/dpqc/DPQC_overparam_visualize.py

# %%
# !python src/unitary_pqc/unitary_pqc_overparam_visualize.py
